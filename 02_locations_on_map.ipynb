# %% [markdown]
# # AirBnb Buenos Aires map

# %%
import pandas as pd
import folium as fl
from folium.plugins import FastMarkerCluster

# %%
df_listings = pd.read_csv("/home/matias/workspace/inside-airbnb-data-visualization/data/listings.csv")
# Out:
# /tmp/ipykernel_40206/4229759872.py:2: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_listings = pd.read_csv("/home/matias/workspace/inside-airbnb-data-visualization/data/listings.csv")

# %%
latitude_values = df_listings['latitude'].tolist()
longitude_values = df_listings['longitude'].tolist()
locations = list(zip(latitude_values, longitude_values))

finalMap = fl.Map(location=[-34.6003, -58.4333], zoom_start=12)
FastMarkerCluster(data=locations).add_to(finalMap)

# %%
finalMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
